# %% [markdown]
# <div class="_1l1MA" data-track-load="qd_description_content"><p>Given an integer array <code>nums</code>, return <code>true</code> if any value appears <strong>at least twice</strong> in the array, and return <code>false</code> if every element is distinct.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <pre><strong>Input:</strong> nums = [1,2,3,1]
# <strong>Output:</strong> true
# </pre><p><strong class="example">Example 2:</strong></p>
# <pre><strong>Input:</strong> nums = [1,2,3,4]
# <strong>Output:</strong> false
# </pre><p><strong class="example">Example 3:</strong></p>
# <pre><strong>Input:</strong> nums = [1,1,1,3,3,4,3,2,4,2]
# <strong>Output:</strong> true
# </pre>
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= nums.length &lt;= 10<sup>5</sup></code></li>
# 	<li><code>-10<sup>9</sup> &lt;= nums[i] &lt;= 10<sup>9</sup></code></li>
# </ul>
# </div>

# %%
class Solution(object):
    def containsDuplicate(self, nums):
        """
        :type nums: List[int]
        :rtype: bool
        """
        save = set()
        for num in nums:
            if num in save:
                return True
            save.add(num)
        return False

# %% [markdown]
# <div class="flex w-full pb-4"><div class="flex flex-none flex-col gap-2 px-4 w-1/2"><div class="w-full overflow-hidden cursor-pointer"><div data-highcharts-chart="8" style="overflow: hidden;"><div id="highcharts-tb2wfzx-299" dir="ltr" class="highcharts-container " style="position: relative; overflow: hidden; width: 242px; height: 50px; text-align: left; line-height: normal; z-index: 0; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); user-select: none; touch-action: manipulation; outline: none;"><svg version="1.1" class="highcharts-root" style="font-family:&quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif;font-size:12px;" xmlns="http://www.w3.org/2000/svg" width="242" height="50" viewBox="0 0 242 50"><desc>Created with Highcharts 9.3.3</desc><defs><clipPath id="highcharts-tb2wfzx-300-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-340-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-341-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath></defs><rect fill="transparent" class="highcharts-background" x="0" y="0" width="242" height="50" rx="0" ry="0"></rect><rect fill="none" class="highcharts-plot-background" x="0" y="0" width="242" height="50"></rect><rect fill="none" class="highcharts-plot-border" data-z-index="1" x="0" y="0" width="242" height="50"></rect><g class="highcharts-grid highcharts-xaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 2.5 0 L 2.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 26.5 0 L 26.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 50.5 0 L 50.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 75.5 0 L 75.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 99.5 0 L 99.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 123.5 0 L 123.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 147.5 0 L 147.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 171.5 0 L 171.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 196.5 0 L 196.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 220.5 0 L 220.5 50" opacity="1"></path></g><g class="highcharts-grid highcharts-yaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 50.5 L 242 50.5" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 0.5 L 242 0.5" opacity="1"></path></g><g class="highcharts-axis highcharts-xaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 50 L 242 50"></path></g><g class="highcharts-axis highcharts-yaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 0 L 0 50"></path></g><g class="highcharts-series-group" data-z-index="3"><g class="highcharts-series highcharts-series-0 highcharts-column-series highcharts-tracker" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="url(#highcharts-tb2wfzx-340-)"><path fill="#C2E0FF" d="M 3 47 L 3 47 C 4 47 5 48 5 49 L 5 49 C 5 50 4 51 3 51 L 3 51 C 2 51 1 50 1 49 L 1 49 C 1 48 2 47 3 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 9 47 L 9 47 C 10 47 11 48 11 49 L 11 49 C 11 50 10 51 9 51 L 9 51 C 8 51 7 50 7 49 L 7 49 C 7 48 8 47 9 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 15 47 L 15 47 C 16 47 17 48 17 49 L 17 49 C 17 50 16 51 15 51 L 15 51 C 14 51 13 50 13 49 L 13 49 C 13 48 14 47 15 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 21 47 L 21 47 C 22 47 23 48 23 49 L 23 49 C 23 50 22 51 21 51 L 21 51 C 20 51 19 50 19 49 L 19 49 C 19 48 20 47 21 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 27 47 L 27 47 C 28 47 29 48 29 49 L 29 49 C 29 50 28 51 27 51 L 27 51 C 26 51 25 50 25 49 L 25 49 C 25 48 26 47 27 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 33 47 L 33 47 C 34 47 35 48 35 49 L 35 49 C 35 50 34 51 33 51 L 33 51 C 32 51 31 50 31 49 L 31 49 C 31 48 32 47 33 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 39 47 L 39 47 C 40 47 41 48 41 49 L 41 49 C 41 50 40 51 39 51 L 39 51 C 38 51 37 50 37 49 L 37 49 C 37 48 38 47 39 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 45 47 L 45 47 C 46 47 47 48 47 49 L 47 49 C 47 50 46 51 45 51 L 45 51 C 44 51 43 50 43 49 L 43 49 C 43 48 44 47 45 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 51 47 L 52 47 C 53 47 54 48 54 49 L 54 49 C 54 50 53 51 52 51 L 51 51 C 50 51 49 50 49 49 L 49 49 C 49 48 50 47 51 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 57 47 L 58 47 C 59 47 60 48 60 49 L 60 49 C 60 50 59 51 58 51 L 57 51 C 56 51 55 50 55 49 L 55 49 C 55 48 56 47 57 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 63 47 L 64 47 C 65 47 66 48 66 49 L 66 49 C 66 50 65 51 64 51 L 63 51 C 62 51 61 50 61 49 L 61 49 C 61 48 62 47 63 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 69 47 L 70 47 C 71 47 72 48 72 49 L 72 49 C 72 50 71 51 70 51 L 69 51 C 68 51 67 50 67 49 L 67 49 C 67 48 68 47 69 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 76 47 L 76 47 C 77 47 78 48 78 49 L 78 49 C 78 50 77 51 76 51 L 76 51 C 75 51 74 50 74 49 L 74 49 C 74 48 75 47 76 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 82 47 L 82 47 C 83 47 84 48 84 49 L 84 49 C 84 50 83 51 82 51 L 82 51 C 81 51 80 50 80 49 L 80 49 C 80 48 81 47 82 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 88 42 L 88 42 C 89 42 90 43 90 44 L 90 49 C 90 50 89 51 88 51 L 88 51 C 87 51 86 50 86 49 L 86 44 C 86 43 87 42 88 42 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 94 34 L 94 34 C 95 34 96 35 96 36 L 96 49 C 96 50 95 51 94 51 L 94 51 C 93 51 92 50 92 49 L 92 36 C 92 35 93 34 94 34 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 100 25 L 100 25 C 101 25 102 26 102 27 L 102 49 C 102 50 101 51 100 51 L 100 51 C 99 51 98 50 98 49 L 98 27 C 98 26 99 25 100 25 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 106 14 L 106 14 C 107 14 108 15 108 16 L 108 49 C 108 50 107 51 106 51 L 106 51 C 105 51 104 50 104 49 L 104 16 C 104 15 105 14 106 14 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 112 13 L 112 13 C 113 13 114 14 114 15 L 114 49 C 114 50 113 51 112 51 L 112 51 C 111 51 110 50 110 49 L 110 15 C 110 14 111 13 112 13 Z" opacity="1" class="highcharts-point"></path><path fill="#007AFF" d="M 118 18 L 118 18 C 119 18 120 19 120 20 L 120 49 C 120 50 119 51 118 51 L 118 51 C 117 51 116 50 116 49 L 116 20 C 116 19 117 18 118 18 Z" opacity="1" class="highcharts-point highcharts-point-select"></path><path fill="#C2E0FF" d="M 124 27 L 124 27 C 125 27 126 28 126 29 L 126 49 C 126 50 125 51 124 51 L 124 51 C 123 51 122 50 122 49 L 122 29 C 122 28 123 27 124 27 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 130 29 L 130 29 C 131 29 132 30 132 31 L 132 49 C 132 50 131 51 130 51 L 130 51 C 129 51 128 50 128 49 L 128 31 C 128 30 129 29 130 29 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 136 42 L 136 42 C 137 42 138 43 138 44 L 138 49 C 138 50 137 51 136 51 L 136 51 C 135 51 134 50 134 49 L 134 44 C 134 43 135 42 136 42 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 142 43 L 142 43 C 143 43 144 44 144 45 L 144 49 C 144 50 143 51 142 51 L 142 51 C 141 51 140 50 140 49 L 140 45 C 140 44 141 43 142 43 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 148 47 L 148 47 C 149 47 150 48 150 49 L 150 49 C 150 50 149 51 148 51 L 148 51 C 147 51 146 50 146 49 L 146 49 C 146 48 147 47 148 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 154 47 L 154 47 C 155 47 156 48 156 49 L 156 49 C 156 50 155 51 154 51 L 154 51 C 153 51 152 50 152 49 L 152 49 C 152 48 153 47 154 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 160 47 L 160 47 C 161 47 162 48 162 49 L 162 49 C 162 50 161 51 160 51 L 160 51 C 159 51 158 50 158 49 L 158 49 C 158 48 159 47 160 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 166 47 L 166 47 C 167 47 168 48 168 49 L 168 49 C 168 50 167 51 166 51 L 166 51 C 165 51 164 50 164 49 L 164 49 C 164 48 165 47 166 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 172 47 L 173 47 C 174 47 175 48 175 49 L 175 49 C 175 50 174 51 173 51 L 172 51 C 171 51 170 50 170 49 L 170 49 C 170 48 171 47 172 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 178 47 L 179 47 C 180 47 181 48 181 49 L 181 49 C 181 50 180 51 179 51 L 178 51 C 177 51 176 50 176 49 L 176 49 C 176 48 177 47 178 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 184 47 L 185 47 C 186 47 187 48 187 49 L 187 49 C 187 50 186 51 185 51 L 184 51 C 183 51 182 50 182 49 L 182 49 C 182 48 183 47 184 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 190 47 L 191 47 C 192 47 193 48 193 49 L 193 49 C 193 50 192 51 191 51 L 190 51 C 189 51 188 50 188 49 L 188 49 C 188 48 189 47 190 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 197 47 L 197 47 C 198 47 199 48 199 49 L 199 49 C 199 50 198 51 197 51 L 197 51 C 196 51 195 50 195 49 L 195 49 C 195 48 196 47 197 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 203 47 L 203 47 C 204 47 205 48 205 49 L 205 49 C 205 50 204 51 203 51 L 203 51 C 202 51 201 50 201 49 L 201 49 C 201 48 202 47 203 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 209 47 L 209 47 C 210 47 211 48 211 49 L 211 49 C 211 50 210 51 209 51 L 209 51 C 208 51 207 50 207 49 L 207 49 C 207 48 208 47 209 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 215 47 L 215 47 C 216 47 217 48 217 49 L 217 49 C 217 50 216 51 215 51 L 215 51 C 214 51 213 50 213 49 L 213 49 C 213 48 214 47 215 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 221 47 L 221 47 C 222 47 223 48 223 49 L 223 49 C 223 50 222 51 221 51 L 221 51 C 220 51 219 50 219 49 L 219 49 C 219 48 220 47 221 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 227 47 L 227 47 C 228 47 229 48 229 49 L 229 49 C 229 50 228 51 227 51 L 227 51 C 226 51 225 50 225 49 L 225 49 C 225 48 226 47 227 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 233 47 L 233 47 C 234 47 235 48 235 49 L 235 49 C 235 50 234 51 233 51 L 233 51 C 232 51 231 50 231 49 L 231 49 C 231 48 232 47 233 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 239 47 L 239 47 C 240 47 241 48 241 49 L 241 49 C 241 50 240 51 239 51 L 239 51 C 238 51 237 50 237 49 L 237 49 C 237 48 238 47 239 47 Z" opacity="1" class="highcharts-point"></path></g><g class="highcharts-markers highcharts-series-0 highcharts-column-series" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="none"></g></g><text x="121" text-anchor="middle" class="highcharts-title" data-z-index="4" style="color:#333333;font-size:18px;fill:#333333;" y="24"></text><text x="121" text-anchor="middle" class="highcharts-subtitle" data-z-index="4" style="color:#666666;fill:#666666;" y="24"></text><text x="10" text-anchor="start" class="highcharts-caption" data-z-index="4" style="color:#666666;fill:#666666;" y="47"></text><g class="highcharts-axis-labels highcharts-xaxis-labels" data-z-index="7"></g><g class="highcharts-axis-labels highcharts-yaxis-labels" data-z-index="7"></g><g class="highcharts-control-points" data-z-index="99" clip-path="url(#highcharts-tb2wfzx-341-)"></g></svg></div></div></div><div class="flex items-center justify-between gap-4 flex-wrap gap-y-2"><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Runtime</span><span class="text-label-1 dark:text-dark-label-1 ml-2 font-medium">495 ms</span></div><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Beats</span><div class="text-white dark:text-dark-white ml-2 rounded-xl px-1.5 font-medium bg-blue-s dark:bg-dark-blue-s"><span>47</span><span class="text-xs">.93%</span></div></div></div></div><div class="flex flex-none flex-col gap-2 px-4 w-1/2"><div class="w-full overflow-hidden cursor-pointer"><div data-highcharts-chart="9" style="overflow: hidden;"><div id="highcharts-tb2wfzx-342" dir="ltr" class="highcharts-container " style="position: relative; overflow: hidden; width: 242px; height: 50px; text-align: left; line-height: normal; z-index: 0; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); user-select: none; touch-action: manipulation; outline: none;"><svg version="1.1" class="highcharts-root" style="font-family:&quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif;font-size:12px;" xmlns="http://www.w3.org/2000/svg" width="242" height="50" viewBox="0 0 242 50"><desc>Created with Highcharts 9.3.3</desc><defs><clipPath id="highcharts-tb2wfzx-343-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-383-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-384-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath></defs><rect fill="transparent" class="highcharts-background" x="0" y="0" width="242" height="50" rx="0" ry="0"></rect><rect fill="none" class="highcharts-plot-background" x="0" y="0" width="242" height="50"></rect><rect fill="none" class="highcharts-plot-border" data-z-index="1" x="0" y="0" width="242" height="50"></rect><g class="highcharts-grid highcharts-xaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 2.5 0 L 2.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 26.5 0 L 26.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 50.5 0 L 50.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 75.5 0 L 75.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 99.5 0 L 99.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 123.5 0 L 123.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 147.5 0 L 147.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 171.5 0 L 171.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 196.5 0 L 196.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 220.5 0 L 220.5 50" opacity="1"></path></g><g class="highcharts-grid highcharts-yaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 50.5 L 242 50.5" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 0.5 L 242 0.5" opacity="1"></path></g><g class="highcharts-axis highcharts-xaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 50 L 242 50"></path></g><g class="highcharts-axis highcharts-yaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 0 L 0 50"></path></g><g class="highcharts-series-group" data-z-index="3"><g class="highcharts-series highcharts-series-0 highcharts-column-series highcharts-tracker" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="url(#highcharts-tb2wfzx-383-)"><path fill="#EBD4F7" d="M 3 47 L 3 47 C 4 47 5 48 5 49 L 5 49 C 5 50 4 51 3 51 L 3 51 C 2 51 1 50 1 49 L 1 49 C 1 48 2 47 3 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 9 47 L 9 47 C 10 47 11 48 11 49 L 11 49 C 11 50 10 51 9 51 L 9 51 C 8 51 7 50 7 49 L 7 49 C 7 48 8 47 9 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 15 47 L 15 47 C 16 47 17 48 17 49 L 17 49 C 17 50 16 51 15 51 L 15 51 C 14 51 13 50 13 49 L 13 49 C 13 48 14 47 15 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 21 47 L 21 47 C 22 47 23 48 23 49 L 23 49 C 23 50 22 51 21 51 L 21 51 C 20 51 19 50 19 49 L 19 49 C 19 48 20 47 21 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 27 47 L 27 47 C 28 47 29 48 29 49 L 29 49 C 29 50 28 51 27 51 L 27 51 C 26 51 25 50 25 49 L 25 49 C 25 48 26 47 27 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 33 47 L 33 47 C 34 47 35 48 35 49 L 35 49 C 35 50 34 51 33 51 L 33 51 C 32 51 31 50 31 49 L 31 49 C 31 48 32 47 33 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 39 47 L 39 47 C 40 47 41 48 41 49 L 41 49 C 41 50 40 51 39 51 L 39 51 C 38 51 37 50 37 49 L 37 49 C 37 48 38 47 39 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 45 47 L 45 47 C 46 47 47 48 47 49 L 47 49 C 47 50 46 51 45 51 L 45 51 C 44 51 43 50 43 49 L 43 49 C 43 48 44 47 45 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 51 47 L 52 47 C 53 47 54 48 54 49 L 54 49 C 54 50 53 51 52 51 L 51 51 C 50 51 49 50 49 49 L 49 49 C 49 48 50 47 51 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 57 47 L 58 47 C 59 47 60 48 60 49 L 60 49 C 60 50 59 51 58 51 L 57 51 C 56 51 55 50 55 49 L 55 49 C 55 48 56 47 57 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 63 47 L 64 47 C 65 47 66 48 66 49 L 66 49 C 66 50 65 51 64 51 L 63 51 C 62 51 61 50 61 49 L 61 49 C 61 48 62 47 63 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 69 47 L 70 47 C 71 47 72 48 72 49 L 72 49 C 72 50 71 51 70 51 L 69 51 C 68 51 67 50 67 49 L 67 49 C 67 48 68 47 69 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 76 47 L 76 47 C 77 47 78 48 78 49 L 78 49 C 78 50 77 51 76 51 L 76 51 C 75 51 74 50 74 49 L 74 49 C 74 48 75 47 76 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 82 47 L 82 47 C 83 47 84 48 84 49 L 84 49 C 84 50 83 51 82 51 L 82 51 C 81 51 80 50 80 49 L 80 49 C 80 48 81 47 82 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 88 47 L 88 47 C 89 47 90 48 90 49 L 90 49 C 90 50 89 51 88 51 L 88 51 C 87 51 86 50 86 49 L 86 49 C 86 48 87 47 88 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 94 47 L 94 47 C 95 47 96 48 96 49 L 96 49 C 96 50 95 51 94 51 L 94 51 C 93 51 92 50 92 49 L 92 49 C 92 48 93 47 94 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 100 47 L 100 47 C 101 47 102 48 102 49 L 102 49 C 102 50 101 51 100 51 L 100 51 C 99 51 98 50 98 49 L 98 49 C 98 48 99 47 100 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 106 47 L 106 47 C 107 47 108 48 108 49 L 108 49 C 108 50 107 51 106 51 L 106 51 C 105 51 104 50 104 49 L 104 49 C 104 48 105 47 106 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 112 47 L 112 47 C 113 47 114 48 114 49 L 114 49 C 114 50 113 51 112 51 L 112 51 C 111 51 110 50 110 49 L 110 49 C 110 48 111 47 112 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 118 47 L 118 47 C 119 47 120 48 120 49 L 120 49 C 120 50 119 51 118 51 L 118 51 C 117 51 116 50 116 49 L 116 49 C 116 48 117 47 118 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 124 47 L 124 47 C 125 47 126 48 126 49 L 126 49 C 126 50 125 51 124 51 L 124 51 C 123 51 122 50 122 49 L 122 49 C 122 48 123 47 124 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 130 47 L 130 47 C 131 47 132 48 132 49 L 132 49 C 132 50 131 51 130 51 L 130 51 C 129 51 128 50 128 49 L 128 49 C 128 48 129 47 130 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 136 47 L 136 47 C 137 47 138 48 138 49 L 138 49 C 138 50 137 51 136 51 L 136 51 C 135 51 134 50 134 49 L 134 49 C 134 48 135 47 136 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 142 47 L 142 47 C 143 47 144 48 144 49 L 144 49 C 144 50 143 51 142 51 L 142 51 C 141 51 140 50 140 49 L 140 49 C 140 48 141 47 142 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 148 47 L 148 47 C 149 47 150 48 150 49 L 150 49 C 150 50 149 51 148 51 L 148 51 C 147 51 146 50 146 49 L 146 49 C 146 48 147 47 148 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 154 47 L 154 47 C 155 47 156 48 156 49 L 156 49 C 156 50 155 51 154 51 L 154 51 C 153 51 152 50 152 49 L 152 49 C 152 48 153 47 154 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 160 43 L 160 43 C 161 43 162 44 162 45 L 162 49 C 162 50 161 51 160 51 L 160 51 C 159 51 158 50 158 49 L 158 45 C 158 44 159 43 160 43 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 166 41 L 166 41 C 167 41 168 42 168 43 L 168 49 C 168 50 167 51 166 51 L 166 51 C 165 51 164 50 164 49 L 164 43 C 164 42 165 41 166 41 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 172 47 L 173 47 C 174 47 175 48 175 49 L 175 49 C 175 50 174 51 173 51 L 172 51 C 171 51 170 50 170 49 L 170 49 C 170 48 171 47 172 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 178 47 L 179 47 C 180 47 181 48 181 49 L 181 49 C 181 50 180 51 179 51 L 178 51 C 177 51 176 50 176 49 L 176 49 C 176 48 177 47 178 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 184 47 L 185 47 C 186 47 187 48 187 49 L 187 49 C 187 50 186 51 185 51 L 184 51 C 183 51 182 50 182 49 L 182 49 C 182 48 183 47 184 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 190 47 L 191 47 C 192 47 193 48 193 49 L 193 49 C 193 50 192 51 191 51 L 190 51 C 189 51 188 50 188 49 L 188 49 C 188 48 189 47 190 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 197 47 L 197 47 C 198 47 199 48 199 49 L 199 49 C 199 50 198 51 197 51 L 197 51 C 196 51 195 50 195 49 L 195 49 C 195 48 196 47 197 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 203 33 L 203 33 C 204 33 205 34 205 35 L 205 49 C 205 50 204 51 203 51 L 203 51 C 202 51 201 50 201 49 L 201 35 C 201 34 202 33 203 33 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 209 41 L 209 41 C 210 41 211 42 211 43 L 211 49 C 211 50 210 51 209 51 L 209 51 C 208 51 207 50 207 49 L 207 43 C 207 42 208 41 209 41 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 215 47 L 215 47 C 216 47 217 48 217 49 L 217 49 C 217 50 216 51 215 51 L 215 51 C 214 51 213 50 213 49 L 213 49 C 213 48 214 47 215 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 221 47 L 221 47 C 222 47 223 48 223 49 L 223 49 C 223 50 222 51 221 51 L 221 51 C 220 51 219 50 219 49 L 219 49 C 219 48 220 47 221 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 227 44 L 227 44 C 228 44 229 45 229 46 L 229 49 C 229 50 228 51 227 51 L 227 51 C 226 51 225 50 225 49 L 225 46 C 225 45 226 44 227 44 Z" opacity="1" class="highcharts-point"></path><path fill="#AF52DE" d="M 233 12 L 233 12 C 234 12 235 13 235 14 L 235 49 C 235 50 234 51 233 51 L 233 51 C 232 51 231 50 231 49 L 231 14 C 231 13 232 12 233 12 Z" opacity="1" class="highcharts-point highcharts-point-select"></path><path fill="#EBD4F7" d="M 239 25 L 239 25 C 240 25 241 26 241 27 L 241 49 C 241 50 240 51 239 51 L 239 51 C 238 51 237 50 237 49 L 237 27 C 237 26 238 25 239 25 Z" opacity="1" class="highcharts-point"></path></g><g class="highcharts-markers highcharts-series-0 highcharts-column-series" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="none"></g></g><text x="121" text-anchor="middle" class="highcharts-title" data-z-index="4" style="color:#333333;font-size:18px;fill:#333333;" y="24"></text><text x="121" text-anchor="middle" class="highcharts-subtitle" data-z-index="4" style="color:#666666;fill:#666666;" y="24"></text><text x="10" text-anchor="start" class="highcharts-caption" data-z-index="4" style="color:#666666;fill:#666666;" y="47"></text><g class="highcharts-axis-labels highcharts-xaxis-labels" data-z-index="7"></g><g class="highcharts-axis-labels highcharts-yaxis-labels" data-z-index="7"></g><g class="highcharts-control-points" data-z-index="99" clip-path="url(#highcharts-tb2wfzx-384-)"></g></svg></div></div></div><div class="flex items-center justify-between gap-4 flex-wrap gap-y-2"><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Memory</span><span class="text-label-1 dark:text-dark-label-1 ml-2 font-medium">29.2 MB</span></div><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Beats</span><div class="text-white dark:text-dark-white ml-2 rounded-xl px-1.5 font-medium bg-purple dark:bg-dark-purple"><span>36</span><span class="text-xs">.58%</span></div></div></div></div></div>

# %%
class Solution(object):
    def containsDuplicate(self, nums):
        """
        :type nums: List[int]
        :rtype: bool
        """
        nums.sort()
        n = len(nums)
        for i in range(n-1):
            if nums[i]==nums[i+1]:
                return True
        return False

# %% [markdown]
# <div class="flex w-full pb-4"><div class="flex flex-none flex-col gap-2 px-4 w-1/2"><div class="w-full overflow-hidden cursor-pointer"><div data-highcharts-chart="8" style="overflow: hidden;"><div id="highcharts-tb2wfzx-299" dir="ltr" class="highcharts-container " style="position: relative; overflow: hidden; width: 242px; height: 50px; text-align: left; line-height: normal; z-index: 0; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); user-select: none; touch-action: manipulation; outline: none;"><svg version="1.1" class="highcharts-root" style="font-family:&quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif;font-size:12px;" xmlns="http://www.w3.org/2000/svg" width="242" height="50" viewBox="0 0 242 50"><desc>Created with Highcharts 9.3.3</desc><defs><clipPath id="highcharts-tb2wfzx-300-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-340-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-341-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath></defs><rect fill="transparent" class="highcharts-background" x="0" y="0" width="242" height="50" rx="0" ry="0"></rect><rect fill="none" class="highcharts-plot-background" x="0" y="0" width="242" height="50"></rect><rect fill="none" class="highcharts-plot-border" data-z-index="1" x="0" y="0" width="242" height="50"></rect><g class="highcharts-grid highcharts-xaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 2.5 0 L 2.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 26.5 0 L 26.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 50.5 0 L 50.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 75.5 0 L 75.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 99.5 0 L 99.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 123.5 0 L 123.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 147.5 0 L 147.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 171.5 0 L 171.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 196.5 0 L 196.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 220.5 0 L 220.5 50" opacity="1"></path></g><g class="highcharts-grid highcharts-yaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 50.5 L 242 50.5" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 0.5 L 242 0.5" opacity="1"></path></g><g class="highcharts-axis highcharts-xaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 50 L 242 50"></path></g><g class="highcharts-axis highcharts-yaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 0 L 0 50"></path></g><g class="highcharts-series-group" data-z-index="3"><g class="highcharts-series highcharts-series-0 highcharts-column-series highcharts-tracker" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="url(#highcharts-tb2wfzx-340-)"><path fill="#C2E0FF" d="M 3 47 L 3 47 C 4 47 5 48 5 49 L 5 49 C 5 50 4 51 3 51 L 3 51 C 2 51 1 50 1 49 L 1 49 C 1 48 2 47 3 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 9 47 L 9 47 C 10 47 11 48 11 49 L 11 49 C 11 50 10 51 9 51 L 9 51 C 8 51 7 50 7 49 L 7 49 C 7 48 8 47 9 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 15 47 L 15 47 C 16 47 17 48 17 49 L 17 49 C 17 50 16 51 15 51 L 15 51 C 14 51 13 50 13 49 L 13 49 C 13 48 14 47 15 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 21 47 L 21 47 C 22 47 23 48 23 49 L 23 49 C 23 50 22 51 21 51 L 21 51 C 20 51 19 50 19 49 L 19 49 C 19 48 20 47 21 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 27 47 L 27 47 C 28 47 29 48 29 49 L 29 49 C 29 50 28 51 27 51 L 27 51 C 26 51 25 50 25 49 L 25 49 C 25 48 26 47 27 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 33 47 L 33 47 C 34 47 35 48 35 49 L 35 49 C 35 50 34 51 33 51 L 33 51 C 32 51 31 50 31 49 L 31 49 C 31 48 32 47 33 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 39 47 L 39 47 C 40 47 41 48 41 49 L 41 49 C 41 50 40 51 39 51 L 39 51 C 38 51 37 50 37 49 L 37 49 C 37 48 38 47 39 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 45 47 L 45 47 C 46 47 47 48 47 49 L 47 49 C 47 50 46 51 45 51 L 45 51 C 44 51 43 50 43 49 L 43 49 C 43 48 44 47 45 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 51 47 L 52 47 C 53 47 54 48 54 49 L 54 49 C 54 50 53 51 52 51 L 51 51 C 50 51 49 50 49 49 L 49 49 C 49 48 50 47 51 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 57 47 L 58 47 C 59 47 60 48 60 49 L 60 49 C 60 50 59 51 58 51 L 57 51 C 56 51 55 50 55 49 L 55 49 C 55 48 56 47 57 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 63 47 L 64 47 C 65 47 66 48 66 49 L 66 49 C 66 50 65 51 64 51 L 63 51 C 62 51 61 50 61 49 L 61 49 C 61 48 62 47 63 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 69 47 L 70 47 C 71 47 72 48 72 49 L 72 49 C 72 50 71 51 70 51 L 69 51 C 68 51 67 50 67 49 L 67 49 C 67 48 68 47 69 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 76 47 L 76 47 C 77 47 78 48 78 49 L 78 49 C 78 50 77 51 76 51 L 76 51 C 75 51 74 50 74 49 L 74 49 C 74 48 75 47 76 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 82 47 L 82 47 C 83 47 84 48 84 49 L 84 49 C 84 50 83 51 82 51 L 82 51 C 81 51 80 50 80 49 L 80 49 C 80 48 81 47 82 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 88 42 L 88 42 C 89 42 90 43 90 44 L 90 49 C 90 50 89 51 88 51 L 88 51 C 87 51 86 50 86 49 L 86 44 C 86 43 87 42 88 42 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 94 34 L 94 34 C 95 34 96 35 96 36 L 96 49 C 96 50 95 51 94 51 L 94 51 C 93 51 92 50 92 49 L 92 36 C 92 35 93 34 94 34 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 100 25 L 100 25 C 101 25 102 26 102 27 L 102 49 C 102 50 101 51 100 51 L 100 51 C 99 51 98 50 98 49 L 98 27 C 98 26 99 25 100 25 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 106 14 L 106 14 C 107 14 108 15 108 16 L 108 49 C 108 50 107 51 106 51 L 106 51 C 105 51 104 50 104 49 L 104 16 C 104 15 105 14 106 14 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 112 13 L 112 13 C 113 13 114 14 114 15 L 114 49 C 114 50 113 51 112 51 L 112 51 C 111 51 110 50 110 49 L 110 15 C 110 14 111 13 112 13 Z" opacity="1" class="highcharts-point"></path><path fill="rgb(194,224,255)" d="M 118 18 L 118 18 C 119 18 120 19 120 20 L 120 49 C 120 50 119 51 118 51 L 118 51 C 117 51 116 50 116 49 L 116 20 C 116 19 117 18 118 18 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 124 27 L 124 27 C 125 27 126 28 126 29 L 126 49 C 126 50 125 51 124 51 L 124 51 C 123 51 122 50 122 49 L 122 29 C 122 28 123 27 124 27 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 130 29 L 130 29 C 131 29 132 30 132 31 L 132 49 C 132 50 131 51 130 51 L 130 51 C 129 51 128 50 128 49 L 128 31 C 128 30 129 29 130 29 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 136 42 L 136 42 C 137 42 138 43 138 44 L 138 49 C 138 50 137 51 136 51 L 136 51 C 135 51 134 50 134 49 L 134 44 C 134 43 135 42 136 42 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 142 43 L 142 43 C 143 43 144 44 144 45 L 144 49 C 144 50 143 51 142 51 L 142 51 C 141 51 140 50 140 49 L 140 45 C 140 44 141 43 142 43 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 148 47 L 148 47 C 149 47 150 48 150 49 L 150 49 C 150 50 149 51 148 51 L 148 51 C 147 51 146 50 146 49 L 146 49 C 146 48 147 47 148 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 154 47 L 154 47 C 155 47 156 48 156 49 L 156 49 C 156 50 155 51 154 51 L 154 51 C 153 51 152 50 152 49 L 152 49 C 152 48 153 47 154 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 160 47 L 160 47 C 161 47 162 48 162 49 L 162 49 C 162 50 161 51 160 51 L 160 51 C 159 51 158 50 158 49 L 158 49 C 158 48 159 47 160 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 166 47 L 166 47 C 167 47 168 48 168 49 L 168 49 C 168 50 167 51 166 51 L 166 51 C 165 51 164 50 164 49 L 164 49 C 164 48 165 47 166 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 172 47 L 173 47 C 174 47 175 48 175 49 L 175 49 C 175 50 174 51 173 51 L 172 51 C 171 51 170 50 170 49 L 170 49 C 170 48 171 47 172 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 178 47 L 179 47 C 180 47 181 48 181 49 L 181 49 C 181 50 180 51 179 51 L 178 51 C 177 51 176 50 176 49 L 176 49 C 176 48 177 47 178 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 184 47 L 185 47 C 186 47 187 48 187 49 L 187 49 C 187 50 186 51 185 51 L 184 51 C 183 51 182 50 182 49 L 182 49 C 182 48 183 47 184 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 190 47 L 191 47 C 192 47 193 48 193 49 L 193 49 C 193 50 192 51 191 51 L 190 51 C 189 51 188 50 188 49 L 188 49 C 188 48 189 47 190 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 197 47 L 197 47 C 198 47 199 48 199 49 L 199 49 C 199 50 198 51 197 51 L 197 51 C 196 51 195 50 195 49 L 195 49 C 195 48 196 47 197 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 203 47 L 203 47 C 204 47 205 48 205 49 L 205 49 C 205 50 204 51 203 51 L 203 51 C 202 51 201 50 201 49 L 201 49 C 201 48 202 47 203 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 209 47 L 209 47 C 210 47 211 48 211 49 L 211 49 C 211 50 210 51 209 51 L 209 51 C 208 51 207 50 207 49 L 207 49 C 207 48 208 47 209 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 215 47 L 215 47 C 216 47 217 48 217 49 L 217 49 C 217 50 216 51 215 51 L 215 51 C 214 51 213 50 213 49 L 213 49 C 213 48 214 47 215 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 221 47 L 221 47 C 222 47 223 48 223 49 L 223 49 C 223 50 222 51 221 51 L 221 51 C 220 51 219 50 219 49 L 219 49 C 219 48 220 47 221 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 227 47 L 227 47 C 228 47 229 48 229 49 L 229 49 C 229 50 228 51 227 51 L 227 51 C 226 51 225 50 225 49 L 225 49 C 225 48 226 47 227 47 Z" opacity="1" class="highcharts-point"></path><path fill="#C2E0FF" d="M 233 47 L 233 47 C 234 47 235 48 235 49 L 235 49 C 235 50 234 51 233 51 L 233 51 C 232 51 231 50 231 49 L 231 49 C 231 48 232 47 233 47 Z" opacity="1" class="highcharts-point"></path><path fill="rgb(0,122,255)" d="M 239 47 L 239 47 C 240 47 241 48 241 49 L 241 49 C 241 50 240 51 239 51 L 239 51 C 238 51 237 50 237 49 L 237 49 C 237 48 238 47 239 47 Z" opacity="1" class="highcharts-point highcharts-point-select"></path></g><g class="highcharts-markers highcharts-series-0 highcharts-column-series" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="none"></g></g><text x="121" text-anchor="middle" class="highcharts-title" data-z-index="4" style="color:#333333;font-size:18px;fill:#333333;" y="24"></text><text x="121" text-anchor="middle" class="highcharts-subtitle" data-z-index="4" style="color:#666666;fill:#666666;" y="24"></text><text x="10" text-anchor="start" class="highcharts-caption" data-z-index="4" style="color:#666666;fill:#666666;" y="47"></text><g class="highcharts-axis-labels highcharts-xaxis-labels" data-z-index="7"></g><g class="highcharts-axis-labels highcharts-yaxis-labels" data-z-index="7"></g><g class="highcharts-control-points" data-z-index="99" clip-path="url(#highcharts-tb2wfzx-341-)"></g></svg></div></div></div><div class="flex items-center justify-between gap-4 flex-wrap gap-y-2"><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Runtime</span><span class="text-label-1 dark:text-dark-label-1 ml-2 font-medium">610 ms</span></div><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Beats</span><div class="text-white dark:text-dark-white ml-2 rounded-xl px-1.5 font-medium bg-blue-s dark:bg-dark-blue-s"><span>5</span><span class="text-xs">.7%</span></div></div></div></div><div class="flex flex-none flex-col gap-2 px-4 w-1/2"><div class="w-full overflow-hidden cursor-pointer"><div data-highcharts-chart="9" style="overflow: hidden;"><div id="highcharts-tb2wfzx-342" dir="ltr" class="highcharts-container " style="position: relative; overflow: hidden; width: 242px; height: 50px; text-align: left; line-height: normal; z-index: 0; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); user-select: none; touch-action: manipulation; outline: none;"><svg version="1.1" class="highcharts-root" style="font-family:&quot;Lucida Grande&quot;, &quot;Lucida Sans Unicode&quot;, Arial, Helvetica, sans-serif;font-size:12px;" xmlns="http://www.w3.org/2000/svg" width="242" height="50" viewBox="0 0 242 50"><desc>Created with Highcharts 9.3.3</desc><defs><clipPath id="highcharts-tb2wfzx-343-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-383-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath><clipPath id="highcharts-tb2wfzx-384-"><rect x="0" y="0" width="242" height="50" fill="none"></rect></clipPath></defs><rect fill="transparent" class="highcharts-background" x="0" y="0" width="242" height="50" rx="0" ry="0"></rect><rect fill="none" class="highcharts-plot-background" x="0" y="0" width="242" height="50"></rect><rect fill="none" class="highcharts-plot-border" data-z-index="1" x="0" y="0" width="242" height="50"></rect><g class="highcharts-grid highcharts-xaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 2.5 0 L 2.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 26.5 0 L 26.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 50.5 0 L 50.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 75.5 0 L 75.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 99.5 0 L 99.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 123.5 0 L 123.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 147.5 0 L 147.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 171.5 0 L 171.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 196.5 0 L 196.5 50" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 220.5 0 L 220.5 50" opacity="1"></path></g><g class="highcharts-grid highcharts-yaxis-grid" data-z-index="1"><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 50.5 L 242 50.5" opacity="1"></path><path fill="none" stroke-dasharray="none" data-z-index="1" class="highcharts-grid-line" d="M 0 0.5 L 242 0.5" opacity="1"></path></g><g class="highcharts-axis highcharts-xaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 50 L 242 50"></path></g><g class="highcharts-axis highcharts-yaxis" data-z-index="2"><path fill="none" class="highcharts-axis-line" data-z-index="7" d="M 0 0 L 0 50"></path></g><g class="highcharts-series-group" data-z-index="3"><g class="highcharts-series highcharts-series-0 highcharts-column-series highcharts-tracker" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="url(#highcharts-tb2wfzx-383-)"><path fill="#EBD4F7" d="M 3 47 L 3 47 C 4 47 5 48 5 49 L 5 49 C 5 50 4 51 3 51 L 3 51 C 2 51 1 50 1 49 L 1 49 C 1 48 2 47 3 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 9 47 L 9 47 C 10 47 11 48 11 49 L 11 49 C 11 50 10 51 9 51 L 9 51 C 8 51 7 50 7 49 L 7 49 C 7 48 8 47 9 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 15 47 L 15 47 C 16 47 17 48 17 49 L 17 49 C 17 50 16 51 15 51 L 15 51 C 14 51 13 50 13 49 L 13 49 C 13 48 14 47 15 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 21 47 L 21 47 C 22 47 23 48 23 49 L 23 49 C 23 50 22 51 21 51 L 21 51 C 20 51 19 50 19 49 L 19 49 C 19 48 20 47 21 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 27 47 L 27 47 C 28 47 29 48 29 49 L 29 49 C 29 50 28 51 27 51 L 27 51 C 26 51 25 50 25 49 L 25 49 C 25 48 26 47 27 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 33 47 L 33 47 C 34 47 35 48 35 49 L 35 49 C 35 50 34 51 33 51 L 33 51 C 32 51 31 50 31 49 L 31 49 C 31 48 32 47 33 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 239 25 L 239 25 C 240 25 241 26 241 27 L 241 49 C 241 50 240 51 239 51 L 239 51 C 238 51 237 50 237 49 L 237 27 C 237 26 238 25 239 25 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 51 47 L 52 47 C 53 47 54 48 54 49 L 54 49 C 54 50 53 51 52 51 L 51 51 C 50 51 49 50 49 49 L 49 49 C 49 48 50 47 51 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 57 47 L 58 47 C 59 47 60 48 60 49 L 60 49 C 60 50 59 51 58 51 L 57 51 C 56 51 55 50 55 49 L 55 49 C 55 48 56 47 57 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 63 47 L 64 47 C 65 47 66 48 66 49 L 66 49 C 66 50 65 51 64 51 L 63 51 C 62 51 61 50 61 49 L 61 49 C 61 48 62 47 63 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 69 47 L 70 47 C 71 47 72 48 72 49 L 72 49 C 72 50 71 51 70 51 L 69 51 C 68 51 67 50 67 49 L 67 49 C 67 48 68 47 69 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 76 47 L 76 47 C 77 47 78 48 78 49 L 78 49 C 78 50 77 51 76 51 L 76 51 C 75 51 74 50 74 49 L 74 49 C 74 48 75 47 76 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 82 47 L 82 47 C 83 47 84 48 84 49 L 84 49 C 84 50 83 51 82 51 L 82 51 C 81 51 80 50 80 49 L 80 49 C 80 48 81 47 82 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 88 47 L 88 47 C 89 47 90 48 90 49 L 90 49 C 90 50 89 51 88 51 L 88 51 C 87 51 86 50 86 49 L 86 49 C 86 48 87 47 88 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 94 47 L 94 47 C 95 47 96 48 96 49 L 96 49 C 96 50 95 51 94 51 L 94 51 C 93 51 92 50 92 49 L 92 49 C 92 48 93 47 94 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 100 47 L 100 47 C 101 47 102 48 102 49 L 102 49 C 102 50 101 51 100 51 L 100 51 C 99 51 98 50 98 49 L 98 49 C 98 48 99 47 100 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 106 47 L 106 47 C 107 47 108 48 108 49 L 108 49 C 108 50 107 51 106 51 L 106 51 C 105 51 104 50 104 49 L 104 49 C 104 48 105 47 106 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 112 47 L 112 47 C 113 47 114 48 114 49 L 114 49 C 114 50 113 51 112 51 L 112 51 C 111 51 110 50 110 49 L 110 49 C 110 48 111 47 112 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 118 47 L 118 47 C 119 47 120 48 120 49 L 120 49 C 120 50 119 51 118 51 L 118 51 C 117 51 116 50 116 49 L 116 49 C 116 48 117 47 118 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 124 47 L 124 47 C 125 47 126 48 126 49 L 126 49 C 126 50 125 51 124 51 L 124 51 C 123 51 122 50 122 49 L 122 49 C 122 48 123 47 124 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 130 47 L 130 47 C 131 47 132 48 132 49 L 132 49 C 132 50 131 51 130 51 L 130 51 C 129 51 128 50 128 49 L 128 49 C 128 48 129 47 130 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 136 47 L 136 47 C 137 47 138 48 138 49 L 138 49 C 138 50 137 51 136 51 L 136 51 C 135 51 134 50 134 49 L 134 49 C 134 48 135 47 136 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 142 47 L 142 47 C 143 47 144 48 144 49 L 144 49 C 144 50 143 51 142 51 L 142 51 C 141 51 140 50 140 49 L 140 49 C 140 48 141 47 142 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 148 47 L 148 47 C 149 47 150 48 150 49 L 150 49 C 150 50 149 51 148 51 L 148 51 C 147 51 146 50 146 49 L 146 49 C 146 48 147 47 148 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 154 47 L 154 47 C 155 47 156 48 156 49 L 156 49 C 156 50 155 51 154 51 L 154 51 C 153 51 152 50 152 49 L 152 49 C 152 48 153 47 154 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 160 43 L 160 43 C 161 43 162 44 162 45 L 162 49 C 162 50 161 51 160 51 L 160 51 C 159 51 158 50 158 49 L 158 45 C 158 44 159 43 160 43 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 166 41 L 166 41 C 167 41 168 42 168 43 L 168 49 C 168 50 167 51 166 51 L 166 51 C 165 51 164 50 164 49 L 164 43 C 164 42 165 41 166 41 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 172 47 L 173 47 C 174 47 175 48 175 49 L 175 49 C 175 50 174 51 173 51 L 172 51 C 171 51 170 50 170 49 L 170 49 C 170 48 171 47 172 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 178 47 L 179 47 C 180 47 181 48 181 49 L 181 49 C 181 50 180 51 179 51 L 178 51 C 177 51 176 50 176 49 L 176 49 C 176 48 177 47 178 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 184 47 L 185 47 C 186 47 187 48 187 49 L 187 49 C 187 50 186 51 185 51 L 184 51 C 183 51 182 50 182 49 L 182 49 C 182 48 183 47 184 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 190 47 L 191 47 C 192 47 193 48 193 49 L 193 49 C 193 50 192 51 191 51 L 190 51 C 189 51 188 50 188 49 L 188 49 C 188 48 189 47 190 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 197 47 L 197 47 C 198 47 199 48 199 49 L 199 49 C 199 50 198 51 197 51 L 197 51 C 196 51 195 50 195 49 L 195 49 C 195 48 196 47 197 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 203 33 L 203 33 C 204 33 205 34 205 35 L 205 49 C 205 50 204 51 203 51 L 203 51 C 202 51 201 50 201 49 L 201 35 C 201 34 202 33 203 33 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 209 41 L 209 41 C 210 41 211 42 211 43 L 211 49 C 211 50 210 51 209 51 L 209 51 C 208 51 207 50 207 49 L 207 43 C 207 42 208 41 209 41 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 215 47 L 215 47 C 216 47 217 48 217 49 L 217 49 C 217 50 216 51 215 51 L 215 51 C 214 51 213 50 213 49 L 213 49 C 213 48 214 47 215 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 221 47 L 221 47 C 222 47 223 48 223 49 L 223 49 C 223 50 222 51 221 51 L 221 51 C 220 51 219 50 219 49 L 219 49 C 219 48 220 47 221 47 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 227 44 L 227 44 C 228 44 229 45 229 46 L 229 49 C 229 50 228 51 227 51 L 227 51 C 226 51 225 50 225 49 L 225 46 C 225 45 226 44 227 44 Z" opacity="1" class="highcharts-point"></path><path fill="#EBD4F7" d="M 233 12 L 233 12 C 234 12 235 13 235 14 L 235 49 C 235 50 234 51 233 51 L 233 51 C 232 51 231 50 231 49 L 231 14 C 231 13 232 12 233 12 Z" opacity="1" class="highcharts-point"></path><path fill="rgb(175,82,222)" d="M 39 47 L 39 47 C 40 47 41 48 41 49 L 41 49 C 41 50 40 51 39 51 L 39 51 C 38 51 37 50 37 49 L 37 49 C 37 48 38 47 39 47 Z" opacity="1" class="highcharts-point highcharts-point-select"></path><path fill="#EBD4F7" d="M 45 47 L 45 47 C 46 47 47 48 47 49 L 47 49 C 47 50 46 51 45 51 L 45 51 C 44 51 43 50 43 49 L 43 49 C 43 48 44 47 45 47 Z" opacity="1" class="highcharts-point"></path></g><g class="highcharts-markers highcharts-series-0 highcharts-column-series" data-z-index="0.1" opacity="1" transform="translate(0,0) scale(1 1)" clip-path="none"></g></g><text x="121" text-anchor="middle" class="highcharts-title" data-z-index="4" style="color:#333333;font-size:18px;fill:#333333;" y="24"></text><text x="121" text-anchor="middle" class="highcharts-subtitle" data-z-index="4" style="color:#666666;fill:#666666;" y="24"></text><text x="10" text-anchor="start" class="highcharts-caption" data-z-index="4" style="color:#666666;fill:#666666;" y="47"></text><g class="highcharts-axis-labels highcharts-xaxis-labels" data-z-index="7"></g><g class="highcharts-axis-labels highcharts-yaxis-labels" data-z-index="7"></g><g class="highcharts-control-points" data-z-index="99" clip-path="url(#highcharts-tb2wfzx-384-)"></g></svg></div></div></div><div class="flex items-center justify-between gap-4 flex-wrap gap-y-2"><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Memory</span><span class="text-label-1 dark:text-dark-label-1 ml-2 font-medium">23 MB</span></div><div class="flex items-center"><span class="text-label-3 dark:text-dark-label-3 text-xs">Beats</span><div class="text-white dark:text-dark-white ml-2 rounded-xl px-1.5 font-medium bg-purple dark:bg-dark-purple"><span>96</span><span class="text-xs">.45%</span></div></div></div></div></div>
